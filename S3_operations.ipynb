# %%
import boto3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Manipulation

# %%
get_it_done = pd.read_csv('get_it_done_2019_requests_datasd.csv')

# %%
get_it_done.head()
# Out:
#    service_request_id   requested_datetime  case_age_days  \
# 0             2475207  2019-01-01T00:20:00            NaN
# 1             2475208  2019-01-01T00:20:00            NaN
# 2             2475209  2019-01-01T00:21:00           15.0
# 3             2475210  2019-01-01T01:06:00           41.0
# 4             2475211  2019-01-01T01:12:00           18.0
#
#                                     service_name      case_record_type  \
# 0                                          Other                   TSW
# 1                                          Other                   TSW
# 2                                         Litter  ESD Complaint/Report
# 3                                Street Sweeping                   TSW
# 4  Engineering - Traffic Calming/Safety Features   Traffic Engineering
#
#       updated_datetime      status        lat        long  district  \
# 0                  NaN    Referred  32.710427 -117.145192       8.0
# ...

# %%
get_it_done.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26038 entries, 0 to 26037
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   service_request_id   26038 non-null  int64
#  1   requested_datetime   26038 non-null  object
#  2   case_age_days        23712 non-null  float64
#  3   service_name         25599 non-null  object
#  4   case_record_type     26038 non-null  object
#  5   updated_datetime     13106 non-null  object
#  6   status               26038 non-null  object
#  7   lat                  26038 non-null  float64
#  8   long                 26038 non-null  float64
#  9   district             25748 non-null  float64
#  10  case_origin          26017 non-null  object
#  11  referred_department  2351 non-null   object
#  12  public_description   21726 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 2.6+ MB

# %%
get_it_done.tail()
# Out:
#        service_request_id   requested_datetime  case_age_days  \
# 26033             2506640  2019-02-10T13:53:00            0.0
# 26034             2506641  2019-02-10T13:54:00            0.0
# 26035             2506642  2019-02-10T13:55:00            0.0
# 26036             2506643  2019-02-10T13:56:00            0.0
# 26037             2506644  2019-02-10T14:01:00            0.0
#
#                       service_name      case_record_type updated_datetime  \
# 26033                      Pothole                   TSW              NaN
# 26034             Graffiti Removal                   TSW              NaN
# 26035            72 Hour Violation               Parking              NaN
# 26036  Traffic Signal Timing Issue                   TSW              NaN
# 26037              Illegal Dumping  ESD Complaint/Report              NaN
#
#            status        lat        long  district case_origin  \
# 26033  In Process  32.924886 -117.254572       1.0      Mobile
# ...

# %%
import dateutil.parser

# %%
yourdate = dateutil.parser.parse('2019-02-10T13:53:00')

# %%
yourdate
# Out:
# datetime.datetime(2019, 2, 10, 13, 53)

# %%
get_it_done['requested_datetime'] = pd.to_datetime(get_it_done['requested_datetime'])

# %%
get_it_done.head()
# Out:
#    service_request_id  requested_datetime  case_age_days  \
# 0             2475207 2019-01-01 00:20:00            NaN
# 1             2475208 2019-01-01 00:20:00            NaN
# 2             2475209 2019-01-01 00:21:00           15.0
# 3             2475210 2019-01-01 01:06:00           41.0
# 4             2475211 2019-01-01 01:12:00           18.0
#
#                                     service_name      case_record_type  \
# 0                                          Other                   TSW
# 1                                          Other                   TSW
# 2                                         Litter  ESD Complaint/Report
# 3                                Street Sweeping                   TSW
# 4  Engineering - Traffic Calming/Safety Features   Traffic Engineering
#
#       updated_datetime      status        lat        long  district  \
# 0                  NaN    Referred  32.710427 -117.145192       8.0
# ...

# %%
get_it_done['requested_date'] = get_it_done['requested_datetime'].dt.date

# %%
get_it_done['requested_date'] = pd.to_datetime(get_it_done['requested_date'])

# %%
get_it_done.head()
# Out:
#    service_request_id  requested_datetime  case_age_days  \
# 0             2475207 2019-01-01 00:20:00            NaN
# 1             2475208 2019-01-01 00:20:00            NaN
# 2             2475209 2019-01-01 00:21:00           15.0
# 3             2475210 2019-01-01 01:06:00           41.0
# 4             2475211 2019-01-01 01:12:00           18.0
#
#                                     service_name      case_record_type  \
# 0                                          Other                   TSW
# 1                                          Other                   TSW
# 2                                         Litter  ESD Complaint/Report
# 3                                Street Sweeping                   TSW
# 4  Engineering - Traffic Calming/Safety Features   Traffic Engineering
#
#       updated_datetime      status        lat        long  district  \
# 0                  NaN    Referred  32.710427 -117.145192       8.0
# ...

# %%
get_it_done.dtypes
# Out:
# service_request_id              int64
# requested_datetime     datetime64[ns]
# case_age_days                 float64
# service_name                   object
# case_record_type               object
# updated_datetime               object
# status                         object
# lat                           float64
# long                          float64
# district                      float64
# case_origin                    object
# referred_department            object
# public_description             object
# requested_date         datetime64[ns]
# dtype: object

# %%
get_it_done[get_it_done['requested_date'] == '2019-01-01']
# Out:
#      service_request_id  requested_datetime  case_age_days  \
# 0               2475207 2019-01-01 00:20:00            NaN
# 1               2475208 2019-01-01 00:20:00            NaN
# 2               2475209 2019-01-01 00:21:00           15.0
# 3               2475210 2019-01-01 01:06:00           41.0
# 4               2475211 2019-01-01 01:12:00           18.0
# ..                  ...                 ...            ...
# 266             2475485 2019-01-01 22:29:00            6.0
# 267             2475486 2019-01-01 22:31:00            6.0
# 268             2475487 2019-01-01 23:11:00            0.0
# 269             2475488 2019-01-01 23:23:00           40.0
# 270             2475489 2019-01-01 23:54:00           28.0
#
#                                       service_name      case_record_type  \
# 0                                            Other                   TSW
# 1                                            Other                   TSW
# ...

# %%
get_it_done.case_record_type.unique()
# Out:
# array(['TSW', 'ESD Complaint/Report', 'Traffic Engineering', 'Parking',
#        'Storm Water Code Enforcement', 'TSW ROW', 'DSD'], dtype=object)

# %%
get_it_done['month'] = get_it_done.requested_date.dt.month

# %%
agg_df = get_it_done.groupby(['case_record_type', 'month'])['case_age_days'].count().reset_index(name='Count')

# %%
agg_df.to_csv('aggregated_report.csv')

# %% [markdown]
# ### S3 bucket creation and upload

# %%
s3 = boto3.client('s3',region_name='us-east-1',
    aws_access_key_id=AWS_KEY_ID,
    aws_secret_access_key=AWS_SECRET)

# %%
# Create Bucket
bucket = s3.create_bucket(Bucket='gid-requests')

# %%
# List Buckets
bucket_response = s3.list_buckets()

# %%
buckets = bucket_response['Buckets']
print(buckets)

# %%
# Uploading the file to bucket while making it public

s3.upload_file(
    Bucket='gid-requests',
    Filename='aggregated_report.csv',
    Key='aggregated_report.csv',
    ExtraArgs={'ACL':'public-read'})

# %%
# Generate Object url string
url = "https://{}.s3.amazonaws.com/{}".format(
"gid-requests",
"aggregated_report.csv")

# %%
print(url)
